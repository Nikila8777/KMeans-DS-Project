# %%
import sys, os
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../src"))

# %%
import sys, os
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../src"))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.clustering_analysis import run_example_mall
from src.image_compression import compress_image, save_compressed

# %%
from src.clustering_analysis import run_example_mall

# %%
run_example_mall("data/Mall_Customers.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_example_mall("data/Mall_Customers.csv")
#
# File D:\KMeans-DS-Project\src\clustering_analysis.py:46, in run_example_mall(path_to_csv)
#      45 def run_example_mall(path_to_csv):
# ---> 46     X, df = load_mall_data(path_to_csv)
#      47     Ks, inertia = elbow_method(X)
#      48     plot_elbow(Ks, inertia)
#
# File D:\KMeans-DS-Project\src\clustering_analysis.py:8, in load_mall_data(path)
#       7 def load_mall_data(path):
# ----> 8     df = pd.read_csv(path)
#       9     X = df[['Annual Income (k$)', 'Spending Score (1-100)']].values
#      10     return X, df
#
# ...

# %%
run_example_mall("../data/Mall_Customers.csv")

# %%
orig, comp, centroids = compress_image("../data/images/pic.jpg", K=8)

# %%
orig, comp, centroids = compress_image("../data/images/pic.jpg", K=8)

plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(orig)
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Compressed (K=8)")
plt.imshow(comp)
plt.axis("off")

save_compressed(comp, "../data/images/pic_compressed_8_from_notebook.jpg")

# %%
orig, comp, centroids = compress_image("../data/images/pic.jpg", K=32)

plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(orig)
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Compressed (K=32)")
plt.imshow(comp)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(968.5), np.float64(1349.5), np.float64(-0.5))
